# %% [markdown]
# ## Problem Definition

# %% [markdown]
# - Date represents weekly retail scan data for Nation retail volume (units) & price
# - Retail scan data comes directly from retailers' cash registers based on actual retail sales of of Hass avocados
# - Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, club, mass, drug, dollar, & military
# - The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags
# - The Product lookup codes (PLU's) in the table are only for Hass avocadoes. Other varieties of avocadoes (e.g. greenskins) are not included in this table
#
# Relevant columns in the dataset:
#
#     - Date - the date of the observation
#     - Average Price - the average price of a single avocado
#     - Type - conventional or organic
#     - Year - The year
#     - Region - The city or the region of the observation
#     - Total Volume - Total # of avocados sold
#     - 4046 - Total # of avocados with PLU 4046 sold
#     - 4225 - Total # of avocados with PLU 4225 sold
#     - 4770 - Total # of avocados with PLU 4770 sold

# %%
#Import the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
from prophet import Prophet

# %%
avocado_df = pd.read_csv('avocado.csv')

# %%
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# ## Data

# %%
#Data visulization
avocado_df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado_df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
avocado_df.head(20)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76   842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86   75595.85
# ...

# %%
avocado_df.tail(20)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 18229           4  2018-02-25          1.49     301985.61  34200.18  49139.34
# 18230           5  2018-02-18          1.64     224798.60  30149.00  38800.64
# 18231           6  2018-02-11          1.47     275248.53  24732.55  61713.53
# 18232           7  2018-02-04          1.41     283378.47  22474.66  55360.49
# 18233           8  2018-01-28          1.80     185974.53  22918.40  33051.14
# 18234           9  2018-01-21          1.83     189317.99  27049.44  33561.32
# 18235          10  2018-01-14          1.82     207999.67  33869.12  47435.14
# 18236          11  2018-01-07          1.48     297190.60  34734.97  62967.74
# 18237           0  2018-03-25          1.62      15303.40   2325.30   2171.66
# 18238           1  2018-03-18          1.56      15896.38   2055.35   1499.55
# 18239           2  2018-03-11          1.56      22128.42   2162.67   3194.25
# ...

# %%
# Data manipulation
avocado_df = avocado_df.sort_values("Date")

# %%
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11569          51  2015-01-04          1.75      27365.89     9307.34
# 9593           51  2015-01-04          1.49      17723.17     1189.35
# 10009          51  2015-01-04          1.68       2896.72      161.68
# 1819           51  2015-01-04          1.52      54956.80     3013.04
# 9333           51  2015-01-04          1.64       1505.12        1.27
# ...           ...         ...           ...           ...         ...
# 8574            0  2018-03-25          1.36     908202.13   142681.06
# 9018            0  2018-03-25          0.70    9010588.32  3999735.71
# 18141           0  2018-03-25          1.42     163496.70    29253.30
# 17673           0  2018-03-25          1.70     190257.38    29644.09
# 8814            0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Plot the data for visualization
plt.figure(figsize=(10, 10))
plt.plot(avocado_df['Date'], avocado_df['AveragePrice']);

# %%
# plotting the elemnts & we want it to count elemnts based on the region
plt.figure(figsize=(25, 12))
sns.countplot(x = 'region', data = avocado_df)
plt.xticks(rotation = 45); #rotates the x-axis so that the labels don't overlap each other

# %%
sns.countplot(x = 'year', data = avocado_df);

# %%
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11569          51  2015-01-04          1.75      27365.89     9307.34
# 9593           51  2015-01-04          1.49      17723.17     1189.35
# 10009          51  2015-01-04          1.68       2896.72      161.68
# 1819           51  2015-01-04          1.52      54956.80     3013.04
# 9333           51  2015-01-04          1.64       1505.12        1.27
# ...           ...         ...           ...           ...         ...
# 8574            0  2018-03-25          1.36     908202.13   142681.06
# 9018            0  2018-03-25          0.70    9010588.32  3999735.71
# 18141           0  2018-03-25          1.42     163496.70    29253.30
# 17673           0  2018-03-25          1.70     190257.38    29644.09
# 8814            0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# extracts the only 2 data columns we need
avocado_prophet_df = avocado_df[['Date', 'AveragePrice']]

# %%
avocado_prophet_df
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64
# ...           ...           ...
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %% [markdown]
# ## Make Predictions

# %%
# In order to run Prophet the columns names must be 'ds' & 'y'
avocado_prophet_df = avocado_prophet_df.rename(columns={'Date': 'ds', 'AveragePrice': 'y'})

# %%
avocado_prophet_df
# Out:
#                ds     y
# 11569  2015-01-04  1.75
# 9593   2015-01-04  1.49
# 10009  2015-01-04  1.68
# 1819   2015-01-04  1.52
# 9333   2015-01-04  1.64
# ...           ...   ...
# 8574   2018-03-25  1.36
# 9018   2018-03-25  0.70
# 18141  2018-03-25  1.42
# 17673  2018-03-25  1.70
# 8814   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
m = Prophet()

# %%
# Fit the model
m.fit(avocado_prophet_df)
# Out:
# 17:48:49 - cmdstanpy - INFO - Chain [1] start processing
# 17:48:53 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Forecast the Future
future = m.make_future_dataframe(periods = 365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.500093    0.919690    1.890622     1.500093     1.500093
# 1   2015-01-11  1.494793    0.901525    1.850040     1.494793     1.494793
# 2   2015-01-18  1.489493    0.897464    1.883610     1.489493     1.489493
# 3   2015-01-25  1.484193    0.865980    1.841626     1.484193     1.484193
# 4   2015-02-01  1.478894    0.870614    1.817115     1.478894     1.478894
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.163694    0.554338    1.591689     0.961104     1.365565
# 530 2019-03-22  1.162962    0.574306    1.608291     0.959698     1.365403
# 531 2019-03-23  1.162229    0.556995    1.625480     0.958514     1.365866
# 532 2019-03-24  1.161497    0.564574    1.628046     0.957076     1.366283
# 533 2019-03-25  1.160764    0.524276    1.582214     0.955254     1.366455
#
# ...

# %%
figure = m.plot(forecast, xlabel = 'Date', ylabel = 'Price')

# %%
figure = m.plot_components(forecast)

# %% [markdown]
# ## Make region specific predictions

# %%
avocado_df = pd.read_csv('avocado.csv')

# %%
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# Create a new sample dataset for region predictions
avocado_df_sample = avocado_df[ avocado_df['region']== 'West']

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2704            0  2015-12-27          0.83    5291979.63  2038443.68
# 2705            1  2015-12-20          0.88    4737649.03  2017331.24
# 2706            2  2015-12-13          0.85    4899439.92  1798995.46
# 2707            3  2015-12-06          0.75    6202513.84  2097720.52
# 2708            4  2015-11-29          0.99    3719603.21  1461861.54
# ...           ...         ...           ...           ...         ...
# 18232           7  2018-02-04          1.41     283378.47    22474.66
# 18233           8  2018-01-28          1.80     185974.53    22918.40
# 18234           9  2018-01-21          1.83     189317.99    27049.44
# 18235          10  2018-01-14          1.82     207999.67    33869.12
# 18236          11  2018-01-07          1.48     297190.60    34734.97
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocado_df_sample = avocado_df_sample.sort_values('Date')

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2755           51  2015-01-04          0.89    5794410.58  2275446.87
# 11881          51  2015-01-04          1.40     187548.30    70313.71
# 2754           50  2015-01-11          0.95    5333097.71  2203111.92
# 11880          50  2015-01-11          1.39     223156.55    80139.16
# 2753           49  2015-01-18          0.96    5475363.01  2431736.63
# ...           ...         ...           ...           ...         ...
# 18227           2  2018-03-11          1.63     264691.87    27566.25
# 18226           1  2018-03-18          1.73     210067.47    33437.98
# 9103            1  2018-03-18          0.99    7254940.65  2099082.66
# 9102            0  2018-03-25          0.93    7667064.46  2567279.74
# 18225           0  2018-03-25          1.60     271723.08    26996.28
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.figure(figsize=(25, 12))
plt.plot(avocado_df_sample['Date'], avocado_df_sample['AveragePrice']);

# %%
avocado_df_sample = avocado_df_sample.rename(columns={'Date': 'ds', 'AveragePrice': 'y'})

# %%
avocado_df_sample
# Out:
#        Unnamed: 0          ds     y  Total Volume        4046        4225  \
# 2755           51  2015-01-04  0.89    5794410.58  2275446.87  2582300.65
# 11881          51  2015-01-04  1.40     187548.30    70313.71    72942.11
# 2754           50  2015-01-11  0.95    5333097.71  2203111.92  2292761.26
# 11880          50  2015-01-11  1.39     223156.55    80139.16   111395.01
# 2753           49  2015-01-18  0.96    5475363.01  2431736.63  2258069.63
# ...           ...         ...   ...           ...         ...         ...
# 18227           2  2018-03-11  1.63     264691.87    27566.25    60383.57
# 18226           1  2018-03-18  1.73     210067.47    33437.98    47165.54
# 9103            1  2018-03-18  0.99    7254940.65  2099082.66  1707752.84
# 9102            0  2018-03-25  0.93    7667064.46  2567279.74  1912986.38
# 18225           0  2018-03-25  1.60     271723.08    26996.28    77861.39
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avocado_df_sample = avocado_df_sample[['ds', 'y']]

# %%
avocado_df_sample
# Out:
#                ds     y
# 2755   2015-01-04  0.89
# 11881  2015-01-04  1.40
# 2754   2015-01-11  0.95
# 11880  2015-01-11  1.39
# 2753   2015-01-18  0.96
# ...           ...   ...
# 18227  2018-03-11  1.63
# 18226  2018-03-18  1.73
# 9103   2018-03-18  0.99
# 9102   2018-03-25  0.93
# 18225  2018-03-25  1.60
#
# [338 rows x 2 columns]

# %%
m = Prophet()

# %%
m.fit(avocado_df_sample)
# Out:
# 18:22:10 - cmdstanpy - INFO - Chain [1] start processing
# 18:22:10 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Forecast the Future
future = m.make_future_dataframe(periods = 365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.244474    0.660479    1.503808     1.244474     1.244474
# 1   2015-01-11  1.243625    0.612656    1.505397     1.243625     1.243625
# 2   2015-01-18  1.242777    0.722729    1.498763     1.242777     1.242777
# 3   2015-01-25  1.241928    0.671625    1.474061     1.241928     1.241928
# 4   2015-02-01  1.241079    0.619865    1.452167     1.241079     1.241079
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.735706    1.091912    1.918217     1.709155     1.763974
# 530 2019-03-22  1.736285    1.111928    1.976674     1.709572     1.764684
# 531 2019-03-23  1.736863    1.088936    1.932833     1.709990     1.765387
# 532 2019-03-24  1.737441    1.140865    1.955805     1.710407     1.766051
# 533 2019-03-25  1.738020    1.117033    1.982311     1.710871     1.766809
#
# ...

# %%
figure = m.plot(forecast, xlabel = 'Date', ylabel = 'Price')

# %%
figure = m.plot_components(forecast)
